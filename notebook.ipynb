# %%
from moles_api_v_3_client.client import AuthenticatedClient

def read_token():
    with open('token.txt') as f:
        return f.readline()

token = read_token()
URL = "https://ceda-moles-master.rancher2.130.246.130.221.nip.io/"
UUID = '7e23b82ec3bdc8e5297c0b623697c559'

CLIENT = AuthenticatedClient(base_url=URL, token=token, verify_ssl=False)

# %%
from moles_api_v_3_client.api.parties import parties_list, parties_create
from moles_api_v_3_client.models.party_write_request import PartyWriteRequest

model = PartyWriteRequest(
    last_name='last name',
    first_name='first name',
    address_line_1='example',
    address_line_2='example'
)

res = parties_create.sync_detailed(client=CLIENT, body=model)

party_write = res.parsed

# %%
res = parties_list.sync_detailed(client=CLIENT, ob_id=party_write.ob_id)
party_read = res.parsed.results[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 res = parties_list.sync_detailed(client=CLIENT, ob_id=party_write.ob_id)
#       2 party_read = res.parsed.results[0]
#
# NameError: name 'parties_list' is not defined

# %%
party_read
# Out:
# PartyRead(ob_id=5179, first_name='first name', last_name='last name', party_type=<PartyTypeEnum.INDIVIDUAL: 'individual'>, description='', delivery_point='HIDDEN', administrative_area='HIDDEN', city='HIDDEN', country='HIDDEN', postal_code='HIDDEN', electronic_email_address='HIDDEN', phone='HIDDEN', online_resource='', responsiblepartyinfo_url='http://localhost:8000/api/v3/rpis/?party_id=5179', additional_properties={})

# %%
from moles_api_v_3_client.api.bboxes import bboxes_create
from moles_api_v_3_client.models.geographic_bounding_box_write_request import GeographicBoundingBoxWriteRequest

model = GeographicBoundingBoxWriteRequest(
    bbox_name="Staging test"
)

response = bboxes_create.sync_detailed(client=CLIENT, body=model)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File ~/Documents/MOLES_API_CLIENT/moles-api-client/venv/lib/python3.13/site-packages/httpx/_transports/default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File ~/Documents/MOLES_API_CLIENT/moles-api-client/venv/lib/python3.13/site-packages/httpx/_transports/default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File ~/Documents/MOLES_API_CLIENT/moles-api-client/venv/lib/python3.13/site-packages/httpcore/_sync/connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
# ...

# %%
response
