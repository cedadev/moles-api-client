# %%
from moles_api_v_3_client.client import AuthenticatedClient

def read_token():
    with open('token.txt') as f:
        return f.readline()

token = read_token()
URL = "http://localhost:8000/"
UUID = '7e23b82ec3bdc8e5297c0b623697c559'

client = AuthenticatedClient(base_url=URL, token=token)

# %% [markdown]
# ### GET

# %%
from moles_api_v_3_client.api.observations import observations_list

response = observations_list.sync_detailed(client=client)
data = response.parsed.results[:5]
data
# Out:
# [ObservationRead(ob_id=11, uuid='7e23b82ec3bdc8e5297c0b623697c559', title='TOVS data onboard POES (1978-1998)', abstract='These data consist of sets of 3-dimensional gridpoint analyses of the stratosphere which are produced by the Met Office using data from the TIROS Operational Vertical Sounder (TOVS) instruments onboard the NOAA (National Ocean and Atmospheric Administration) operational polar orbiters. TOVS consists of 3 instruments, the Stratospheric Sounding Unit (SSU) the Microwave Sounding Unit (MSU) and the High Resolution Infrared Sounder (HIRS). Daily radiance and geopotential height data are available on a 5 degree latitude / longitude global grid from December 1978 to April 1997. Software is provided to derive potential vorticity. Access permission required so that PI can monitor usage of data.', creation_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 183554, tzinfo=tzutc()), last_updated_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 272326, tzinfo=tzutc()), latest_data_update_time=datetime.datetime(2004, 4, 21, 10, 50, 45, tzinfo=tzutc()), update_frequency=<UpdateFrequencyEnum.NOTPLANNED: 'notPlanned'>, data_lineage='VMS files originally supplied to the BADC by the Met Office. Later data were supplied in the PP format.', removed_data_reason='', keywords='ATMOSPHERICTEMPERATURE ATMOSPHERE ALTITUDE', publication_state=<PublicationStateCbbEnum.PUBLISHED: 'published'>, non_geographic_flag=False, dont_harvest_from_projects=False, language=<LanguageEnum.ENGLISH: 'English'>, resolution='5 x 5 deg grid', status=<StatusEnum.COMPLETED: 'completed'>, data_published_time=datetime.datetime(2007, 1, 10, 16, 29, 17, tzinfo=tzutc()), doi_published_time=None, removed_data_time=None, geographic_extent=GeographicBoundingBoxRead(ob_id=1, bbox_name='', east_bound_longitude=180.0, west_bound_longitude=-180.0, south_bound_latitude=-90.0, north_bound_latitude=90.0, additional_properties={}), vertical_extent=None, result_field=RelatedResult(ob_id=12, data_path='/badc/ukmo-tovs/data', old_data_path=[], storage_location=<StorageLocationEnum.INTERNAL: 'internal'>, storage_status=<StorageStatusEnum.ONLINE: 'online'>, volume=2952391620, number_of_files=3049, file_format="The monthly data files are held at the BADC in the original VMS binary data format in which the data are encoded into 2-byte integer arrays, in records which contain a single day's data. The simplicity of the data format allows the data to be read on a wide variety of computer platforms with only very minor changes to the access routines.\r\n\r\nSee documentation links for further information on these formats.", additional_properties={}), time_period=TimePeriod(ob_id=3, start_time=datetime.datetime(1978, 12, 1, 0, 0, tzinfo=tzutc()), end_time=datetime.datetime(1998, 6, 29, 23, 0, tzinfo=tzutc()), additional_properties={}), result_quality=DQConformanceResultRead(ob_id=2, explanation='See dataset associated documentation.', passes_test=True, result_title='CEDA Data Quality Statement', date=datetime.date(2012, 8, 15), additional_properties={}), valid_time_period=None, procedure_acquisition=SimpleRead(ob_id=33146, uuid='d5436a7c6e20464e94a7d6bf62c88c3d', short_code='acq', title='TOVS data acquisition onboard POES (1978-1998)', additional_properties={}), procedure_computation=None, procedure_composite_process=None, image_details=[], discovery_keywords=[DiscoveryServiceIdRead(ob_id=1138, name='NDGO0003', additional_properties={})], permissions=[ConstraintsRead(ob_id=2630, access_constraints=None, access_category=<AccessCategoryEnum.RESTRICTED: 'restricted'>, access_roles='tovs', label='restricted: tovs group', licence=LicenceRead(ob_id=12, licence_url='https://artefacts.ceda.ac.uk/licences/specific_licences/ukmo_agreement.pdf', licence_classifications=[LicenceClassificationRead(ob_id=4, classification='academic', additional_properties={})], additional_properties={}), additional_properties={})], projects=[SimpleRead(ob_id=4, uuid='fab53ee460e05f1b68e23657f4b6c5f4', short_code='proj' ...
#  ObservationRead(ob_id=25, uuid='b621ef77b07d3c8e116b5b31fd5eb92b', title='Daily Mean, Minimum and Maximum Central England Temperature series', abstract='The longest available instrumental record of temperature in the world is now available at the BADC. The daily data starts in 1772. \r\n\r\nThe mean, minimum and maximum datasets are updated monthly, with data for a month usually available by the 3rd of the next month. A provisional CET value for the current month is calculated on a daily basis. The mean daily data series begins in 1772. Mean maximum and minimum daily and monthly data are also available, beginning in 1878. Yearly files are provided from 1998 onwards.\r\n\r\nThese historical temperature series are representative of the Midlands region in England, UK (a roughly triangular area of the United Kingdom enclosed by Bristol, Lancashire and London). \r\n\r\nThe following stations are used by the Met Office to compile the CET data: Rothamsted, Malvern, Squires Gate and Ringway.\r\n\r\nBut in November 2004, the weather station Stonyhurst replaced Ringway and revised urban warming and bias adjustments have now been applied to the Stonyhurst data after a period of reduced reliability from the station in the summer months. \r\n\r\nThe data set is compiled by the Met Office Hadley Centre.', creation_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 183554, tzinfo=tzutc()), last_updated_date=datetime.datetime(2022, 7, 22, 9, 15, 57, tzinfo=tzutc()), latest_data_update_time=datetime.datetime(2025, 1, 23, 14, 26, 19, tzinfo=tzutc()), update_frequency=<UpdateFrequencyEnum.NOTPLANNED: 'notPlanned'>, data_lineage='HadCET was acquired in 1998 by the BADC from the Met Office Hadley Centre and was routinely updated until August 2022.', removed_data_reason='', keywords='HadCET, temperature, Hadley, Met Office', publication_state=<PublicationStateCbbEnum.PUBLISHED: 'published'>, non_geographic_flag=False, dont_harvest_from_projects=False, language=<LanguageEnum.ENGLISH: 'English'>, resolution='', status=<StatusEnum.SUPERSEDED: 'superseded'>, data_published_time=datetime.datetime(2007, 1, 5, 23, 59, 30, tzinfo=tzutc()), doi_published_time=None, removed_data_time=None, geographic_extent=GeographicBoundingBoxRead(ob_id=2, bbox_name='', east_bound_longitude=1.0, west_bound_longitude=-4.0, south_bound_latitude=51.0, north_bound_latitude=54.0, additional_properties={}), vertical_extent=None, result_field=RelatedResult(ob_id=26, data_path='/badc/ukmo-cet/data/v1.0.0.0/daily', old_data_path=[43425], storage_location=<StorageLocationEnum.INTERNAL: 'internal'>, storage_status=<StorageStatusEnum.ONLINE: 'online'>, volume=1565592, number_of_files=78, file_format='ASCII', additional_properties={}), time_period=TimePeriod(ob_id=7, start_time=datetime.datetime(1772, 1, 1, 0, 0, tzinfo=tzutc()), end_time=datetime.datetime(2022, 7, 31, 23, 59, 59, tzinfo=tzutc()), additional_properties={}), result_quality=DQConformanceResultRead(ob_id=4, explanation='Data is quality-controlled by the Met Office.', passes_test=True, result_title='CEDA Data Quality Statement', date=datetime.date(2014, 1, 28), additional_properties={}), valid_time_period=None, procedure_acquisition=SimpleRead(ob_id=40, uuid='a4f4617005c54c79a578be4533963e6e', short_code='acq', title='Acquisition Process for: Daily Central England Temperature series', additional_properties={}), procedure_computation=None, procedure_composite_process=None, image_details=[157], discovery_keywords=[DiscoveryServiceIdRead(ob_id=1138, name='NDGO0003', additional_properties={})], permissions=[ConstraintsRead(ob_id=2526, access_constraints=None, access_category=<AccessCategoryEnum.PUBLIC: 'public'>, access_roles=None, label='public: None group', licence=LicenceRead(ob_id=3, licence_url='http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/', licence_classifications=[LicenceClassificationRead(ob_id=3, classification='any', additional_properties={})], additional_properties={}), additional_propertie ...
#  ObservationRead(ob_id=68, uuid='aa9396466823e037fe830b6f4dc59caa', title='OP3-1 Campaign: York BVOCs Dual Column GC-fid 1 measurements at Bukit Atur', abstract='This dataset contains measurements of isoprene, pinene, camphene, d-3-carene, gamma-terpinene, limonene, methacrolein (pptv), methyl vinyl ketone and ethanol.\r\n\r\nOxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest (OP3-Danum-08) is a 3-year Consortium Grant of the Natural Environment Research Council (NERC), beginning 1 October 2007.\r\n\r\nThe objectives of the OP3 project are (i) to understand how emissions of reactive trace gases from a tropical rain forest mediate the production and processing of oxidants and particles in the troposphere, and (ii) to better understand the impact of these processes on local, regional and global scale atmospheric composition, chemistry and climate.', creation_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 183554, tzinfo=tzutc()), last_updated_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 272326, tzinfo=tzutc()), latest_data_update_time=datetime.datetime(2009, 8, 24, 10, 46, 29, tzinfo=tzutc()), update_frequency=<UpdateFrequencyEnum.NOTPLANNED: 'notPlanned'>, data_lineage='Data were obtained during ground-based measurement periods at the Danum Valley Research centre (7th April - 4th May 2008 and 21st June - 27th July 2008), and by the FAAM (Facility for Airborne Atmospheric Measurements) BAe 146 aircraft. Data were provided to the BADC as the OP3 campaign was underway, but may be updated with additional data.', removed_data_reason='', keywords='OP3-1, Chemistry', publication_state=<PublicationStateCbbEnum.PUBLISHED: 'published'>, non_geographic_flag=False, dont_harvest_from_projects=False, language=<LanguageEnum.ENGLISH: 'English'>, resolution='', status=<StatusEnum.COMPLETED: 'completed'>, data_published_time=datetime.datetime(2009, 7, 16, 16, 8, 39, tzinfo=tzutc()), doi_published_time=None, removed_data_time=None, geographic_extent=GeographicBoundingBoxRead(ob_id=3, bbox_name='', east_bound_longitude=118.0, west_bound_longitude=117.0, south_bound_latitude=4.5, north_bound_latitude=5.5, additional_properties={}), vertical_extent=None, result_field=RelatedResult(ob_id=69, data_path='/badc/op3/data/op3-1/york-dc-gc-fid1/2008', old_data_path=[], storage_location=<StorageLocationEnum.INTERNAL: 'internal'>, storage_status=<StorageStatusEnum.ONLINE: 'online'>, volume=166179, number_of_files=2, file_format='Data are NASA Ames formatted', additional_properties={}), time_period=TimePeriod(ob_id=29, start_time=datetime.datetime(2008, 4, 3, 23, 0, tzinfo=tzutc()), end_time=datetime.datetime(2008, 4, 5, 23, 0, tzinfo=tzutc()), additional_properties={}), result_quality=DQConformanceResultRead(ob_id=11, explanation='Research data from the OP3 campaign.', passes_test=True, result_title='CEDA Data Quality Statement', date=datetime.date(2014, 1, 26), additional_properties={}), valid_time_period=None, procedure_acquisition=SimpleRead(ob_id=72, uuid='2bda74813cc74c9a999564c955834ae3', short_code='acq', title='Acquisition Process for: Data from York: Dual Column Gas Chromatograph-Flame Ionization Detector 1 (DC-GC-FID1) at Bukit Atur for the OP3-1 Campaign', additional_properties={}), procedure_computation=None, procedure_composite_process=None, image_details=[2], discovery_keywords=[DiscoveryServiceIdRead(ob_id=1138, name='NDGO0003', additional_properties={})], permissions=[ConstraintsRead(ob_id=2526, access_constraints=None, access_category=<AccessCategoryEnum.PUBLIC: 'public'>, access_roles=None, label='public: None group', licence=LicenceRead(ob_id=3, licence_url='http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/', licence_classifications=[LicenceClassificationRead(ob_id=3, classification='any', additional_properties={})], additional_properties={}), additional_properties={})], projects=[SimpleRead(ob_id=70, uuid='f1de8b892d4093efb05caaba735a03c7', short_code='proj', title='Oxidant  ...
#  ObservationRead(ob_id=73, uuid='acc3884901adeb08f1f6a0d7c5f3e5c0', title='OP3-1 Campaign: York Alkane Dual Column GC-fid 2 measurements at Bukit Atur', abstract='This dataset contains measurements of ethane, propane, butane, cyclopentane, pentane and hexane.\r\n\r\nOxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest (OP3-Danum-08) is a 3-year Consortium Grant of the Natural Environment Research Council (NERC), beginning 1 October 2007.\r\n\r\nThe objectives of the OP3 project are (i) to understand how emissions of reactive trace gases from a tropical rain forest mediate the production and processing of oxidants and particles in the troposphere, and (ii) to better understand the impact of these processes on local, regional and global scale atmospheric composition, chemistry and climate.', creation_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 183554, tzinfo=tzutc()), last_updated_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 272326, tzinfo=tzutc()), latest_data_update_time=datetime.datetime(2009, 8, 24, 10, 48, 23, tzinfo=tzutc()), update_frequency=<UpdateFrequencyEnum.NOTPLANNED: 'notPlanned'>, data_lineage='Data were obtained during ground-based measurement periods at the Danum Valley Research centre (7th April - 4th May 2008 and 21st June - 27th July 2008), and by the FAAM (Facility for Airborne Atmospheric Measurements) BAe 146 aircraft. Data were provided to the BADC as the OP3 campaign was underway, but may be updated with additional data.', removed_data_reason='', keywords='OP3-1, Chemistry', publication_state=<PublicationStateCbbEnum.PUBLISHED: 'published'>, non_geographic_flag=False, dont_harvest_from_projects=False, language=<LanguageEnum.ENGLISH: 'English'>, resolution='', status=<StatusEnum.COMPLETED: 'completed'>, data_published_time=datetime.datetime(2009, 7, 16, 16, 17, 58, tzinfo=tzutc()), doi_published_time=None, removed_data_time=None, geographic_extent=GeographicBoundingBoxRead(ob_id=3, bbox_name='', east_bound_longitude=118.0, west_bound_longitude=117.0, south_bound_latitude=4.5, north_bound_latitude=5.5, additional_properties={}), vertical_extent=None, result_field=RelatedResult(ob_id=74, data_path='/badc/op3/data/op3-1/york-dc-gc-fid2/2008', old_data_path=[], storage_location=<StorageLocationEnum.INTERNAL: 'internal'>, storage_status=<StorageStatusEnum.ONLINE: 'online'>, volume=165946, number_of_files=2, file_format='Data are NASA Ames formatted', additional_properties={}), time_period=TimePeriod(ob_id=30, start_time=datetime.datetime(2008, 4, 3, 23, 0, tzinfo=tzutc()), end_time=datetime.datetime(2008, 4, 5, 23, 0, tzinfo=tzutc()), additional_properties={}), result_quality=DQConformanceResultRead(ob_id=12, explanation='Research data from the OP3 campaign.', passes_test=True, result_title='CEDA Data Quality Statement', date=datetime.date(2014, 1, 26), additional_properties={}), valid_time_period=None, procedure_acquisition=SimpleRead(ob_id=76, uuid='632bca88a12341a9b79068290e607e7d', short_code='acq', title='Acquisition Process for: Data from York: Dual Column GC-fid 2 at Bukit Atur for the OP3-1 Campaign', additional_properties={}), procedure_computation=None, procedure_composite_process=None, image_details=[2], discovery_keywords=[DiscoveryServiceIdRead(ob_id=1138, name='NDGO0003', additional_properties={})], permissions=[ConstraintsRead(ob_id=2526, access_constraints=None, access_category=<AccessCategoryEnum.PUBLIC: 'public'>, access_roles=None, label='public: None group', licence=LicenceRead(ob_id=3, licence_url='http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/', licence_classifications=[LicenceClassificationRead(ob_id=3, classification='any', additional_properties={})], additional_properties={}), additional_properties={})], projects=[SimpleRead(ob_id=70, uuid='f1de8b892d4093efb05caaba735a03c7', short_code='proj', title='Oxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest (OP3-1) Project', additiona ...
#  ObservationRead(ob_id=77, uuid='dffc81d0f46ba70a60b21ca2eae13239', title='OP3-1 Campaign: York Alkene Dual Column GC-fid 2 measurements at Bukit Atur', abstract='This dataset contains measurements of ethene, propene and acetylene.\r\n\r\nOxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest (OP3-Danum-08) is a 3-year Consortium Grant of the Natural Environment Research Council (NERC), beginning 1 October 2007.\r\n\r\nThe objectives of the OP3 project are (i) to understand how emissions of reactive trace gases from a tropical rain forest mediate the production and processing of oxidants and particles in the troposphere, and (ii) to better understand the impact of these processes on local, regional and global scale atmospheric composition, chemistry and climate.', creation_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 183554, tzinfo=tzutc()), last_updated_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 272326, tzinfo=tzutc()), latest_data_update_time=datetime.datetime(2009, 8, 24, 10, 51, 18, tzinfo=tzutc()), update_frequency=<UpdateFrequencyEnum.NOTPLANNED: 'notPlanned'>, data_lineage='Data were obtained during ground-based measurement periods at the Danum Valley Research centre (7th April - 4th May 2008 and 21st June - 27th July 2008), and by the FAAM (Facility for Airborne Atmospheric Measurements) BAe 146 aircraft. Data were provided to the BADC as the OP3 campaign was underway, but may be updated with additional data.', removed_data_reason='', keywords='OP3-1, Chemistry', publication_state=<PublicationStateCbbEnum.PUBLISHED: 'published'>, non_geographic_flag=False, dont_harvest_from_projects=False, language=<LanguageEnum.ENGLISH: 'English'>, resolution='', status=<StatusEnum.COMPLETED: 'completed'>, data_published_time=datetime.datetime(2009, 7, 16, 16, 18, 59, tzinfo=tzutc()), doi_published_time=None, removed_data_time=None, geographic_extent=GeographicBoundingBoxRead(ob_id=3, bbox_name='', east_bound_longitude=118.0, west_bound_longitude=117.0, south_bound_latitude=4.5, north_bound_latitude=5.5, additional_properties={}), vertical_extent=None, result_field=RelatedResult(ob_id=78, data_path='/badc/op3/data/op3-1/york-dc-gc-fid3/2008', old_data_path=[], storage_location=<StorageLocationEnum.INTERNAL: 'internal'>, storage_status=<StorageStatusEnum.ONLINE: 'online'>, volume=76168, number_of_files=2, file_format='Data are NASA Ames formatted', additional_properties={}), time_period=TimePeriod(ob_id=31, start_time=datetime.datetime(2008, 4, 3, 23, 0, tzinfo=tzutc()), end_time=datetime.datetime(2008, 4, 5, 23, 0, tzinfo=tzutc()), additional_properties={}), result_quality=DQConformanceResultRead(ob_id=13, explanation='Research data from the OP3 campaign.', passes_test=True, result_title='CEDA Data Quality Statement', date=datetime.date(2014, 1, 26), additional_properties={}), valid_time_period=None, procedure_acquisition=SimpleRead(ob_id=80, uuid='f5357b4d85a040ca9557e4dd3a474126', short_code='acq', title='Acquisition Process for: Data from York: Dual Column GC-fid 3 at Bukit Atur for the OP3-1 Campaign', additional_properties={}), procedure_computation=None, procedure_composite_process=None, image_details=[2], discovery_keywords=[DiscoveryServiceIdRead(ob_id=1138, name='NDGO0003', additional_properties={})], permissions=[ConstraintsRead(ob_id=2526, access_constraints=None, access_category=<AccessCategoryEnum.PUBLIC: 'public'>, access_roles=None, label='public: None group', licence=LicenceRead(ob_id=3, licence_url='http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/', licence_classifications=[LicenceClassificationRead(ob_id=3, classification='any', additional_properties={})], additional_properties={}), additional_properties={})], projects=[SimpleRead(ob_id=70, uuid='f1de8b892d4093efb05caaba735a03c7', short_code='proj', title='Oxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest (OP3-1) Project', additional_properties={})], inspire_th ...

# %%
for ob in data:
    print(ob.observationcollection_set)
# Out:
# [SimpleRead(ob_id=1, uuid='3b1a86cc61824d78ce195dc21b661c74', short_code='coll', title='Met Office TOVS (TIROS Operational Vertical Sounder) Stratospheric Analyses', additional_properties={})]
# [SimpleRead(ob_id=24, uuid='a946415f9345f6da9bf4c475c19477b6', short_code='coll', title='Met Office Hadley Centre Central England Temperature (HadCET) Series', additional_properties={}), SimpleRead(ob_id=43588, uuid='f1e8696c6d5746e694fde4d6022e5a36', short_code='coll', title='Met Office Hadley Centre Central England Temperature (HadCET) All Versions Collection', additional_properties={})]
# [SimpleRead(ob_id=47, uuid='9279c7e807a2ef0eb78a03c3821e62c4', short_code='coll', title='OP3 Project: Airborne and Ground-based Meteorological Instruments Records as part of the Oxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest', additional_properties={})]
# [SimpleRead(ob_id=47, uuid='9279c7e807a2ef0eb78a03c3821e62c4', short_code='coll', title='OP3 Project: Airborne and Ground-based Meteorological Instruments Records as part of the Oxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest', additional_properties={})]
# [SimpleRead(ob_id=47, uuid='9279c7e807a2ef0eb78a03c3821e62c4', short_code='coll', title='OP3 Project: Airborne and Ground-based Meteorological Instruments Records as part of the Oxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest', additional_properties={})]

# %% [markdown]
# ### POST

# %%
from moles_api_v_3_client.api.observations import observations_create
from moles_api_v_3_client.models.observation_write_request import ObservationWriteRequest, StatusEnum

model = ObservationWriteRequest(
    title='Example12344',
    status=StatusEnum.ONGOING
)

response = observations_create.sync_detailed(client=client, body=model)

# %% [markdown]
# ### Get obs, list of uuids

# %%
from moles_api_v_3_client.api.observations import observations_list

response = observations_list.sync_detailed(client=client, uuid_in=['7e23b82ec3bdc8e5297c0b623697c559', 'b621ef77b07d3c8e116b5b31fd5eb92b', 'aa9396466823e037fe830b6f4dc59caa'])
response.parsed
# Out:
# PaginatedObservationReadList(count=3, results=[ObservationRead(ob_id=11, uuid='7e23b82ec3bdc8e5297c0b623697c559', title='TOVS data onboard POES (1978-1998)', abstract='These data consist of sets of 3-dimensional gridpoint analyses of the stratosphere which are produced by the Met Office using data from the TIROS Operational Vertical Sounder (TOVS) instruments onboard the NOAA (National Ocean and Atmospheric Administration) operational polar orbiters. TOVS consists of 3 instruments, the Stratospheric Sounding Unit (SSU) the Microwave Sounding Unit (MSU) and the High Resolution Infrared Sounder (HIRS). Daily radiance and geopotential height data are available on a 5 degree latitude / longitude global grid from December 1978 to April 1997. Software is provided to derive potential vorticity. Access permission required so that PI can monitor usage of data.', creation_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 183554, tzinfo=tzutc()), last_updated_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 272326, tzinfo=tzutc()), latest_data_update_time=datetime.datetime(2004, 4, 21, 10, 50, 45, tzinfo=tzutc()), update_frequency=<UpdateFrequencyEnum.NOTPLANNED: 'notPlanned'>, data_lineage='VMS files originally supplied to the BADC by the Met Office. Later data were supplied in the PP format.', removed_data_reason='', keywords='ATMOSPHERICTEMPERATURE ATMOSPHERE ALTITUDE', publication_state=<PublicationStateCbbEnum.PUBLISHED: 'published'>, non_geographic_flag=False, dont_harvest_from_projects=False, language=<LanguageEnum.ENGLISH: 'English'>, resolution='5 x 5 deg grid', status=<StatusEnum.COMPLETED: 'completed'>, data_published_time=datetime.datetime(2007, 1, 10, 16, 29, 17, tzinfo=tzutc()), doi_published_time=None, removed_data_time=None, geographic_extent=GeographicBoundingBoxRead(ob_id=1, bbox_name='', east_bound_longitude=180.0, west_bound_longitude=-180.0, south_bound_latitude=-90.0, north_bound_latitude=90.0, additional_properties={}), vertical_extent=None, result_field=RelatedResult(ob_id=12, data_path='/badc/ukmo-tovs/data', old_data_path=[], storage_location=<StorageLocationEnum.INTERNAL: 'internal'>, storage_status=<StorageStatusEnum.ONLINE: 'online'>, volume=2952391620, number_of_files=3049, file_format="The monthly data files are held at the BADC in the original VMS binary data format in which the data are encoded into 2-byte integer arrays, in records which contain a single day's data. The simplicity of the data format allows the data to be read on a wide variety of computer platforms with only very minor changes to the access routines.\r\n\r\nSee documentation links for further information on these formats.", additional_properties={}), time_period=TimePeriod(ob_id=3, start_time=datetime.datetime(1978, 12, 1, 0, 0, tzinfo=tzutc()), end_time=datetime.datetime(1998, 6, 29, 23, 0, tzinfo=tzutc()), additional_properties={}), result_quality=DQConformanceResultRead(ob_id=2, explanation='See dataset associated documentation.', passes_test=True, result_title='CEDA Data Quality Statement', date=datetime.date(2012, 8, 15), additional_properties={}), valid_time_period=None, procedure_acquisition=SimpleRead(ob_id=33146, uuid='d5436a7c6e20464e94a7d6bf62c88c3d', short_code='acq', title='TOVS data acquisition onboard POES (1978-1998)', additional_properties={}), procedure_computation=None, procedure_composite_process=None, image_details=[], discovery_keywords=[DiscoveryServiceIdRead(ob_id=1138, name='NDGO0003', additional_properties={})], permissions=[ConstraintsRead(ob_id=2630, access_constraints=None, access_category=<AccessCategoryEnum.RESTRICTED: 'restricted'>, access_roles='tovs', label='restricted: tovs group', licence=LicenceRead(ob_id=12, licence_url='https://artefacts.ceda.ac.uk/licences/specific_licences/ukmo_agreement.pdf', licence_classifications=[LicenceClassificationRead(ob_id=4, classification='academic', additional_properties={})], additional_properties={}), additional_properties={})], projects=[SimpleRead(ob_id=4, uuid='fab53e ...

# %%
response
# Out:
# Response(status_code=<HTTPStatus.OK: 200>, content=b'{"count":3,"next":null,"previous":null,"results":[{"ob_id":11,"uuid":"7e23b82ec3bdc8e5297c0b623697c559","title":"TOVS data onboard POES (1978-1998)","abstract":"These data consist of sets of 3-dimensional gridpoint analyses of the stratosphere which are produced by the Met Office using data from the TIROS Operational Vertical Sounder (TOVS) instruments onboard the NOAA (National Ocean and Atmospheric Administration) operational polar orbiters. TOVS consists of 3 instruments, the Stratospheric Sounding Unit (SSU) the Microwave Sounding Unit (MSU) and the High Resolution Infrared Sounder (HIRS). Daily radiance and geopotential height data are available on a 5 degree latitude / longitude global grid from December 1978 to April 1997. Software is provided to derive potential vorticity. Access permission required so that PI can monitor usage of data.","creationDate":"2022-07-22T09:15:57.183554Z","lastUpdatedDate":"2022-07-22T09:15:57.272326Z","latestDataUpdateTime":"2004-04-21T10:50:45Z","updateFrequency":"notPlanned","dataLineage":"VMS files originally supplied to the BADC by the Met Office. Later data were supplied in the PP format.","removedDataReason":"","keywords":"ATMOSPHERICTEMPERATURE ATMOSPHERE ALTITUDE","publicationState":"published","nonGeographicFlag":false,"dontHarvestFromProjects":false,"language":"English","resolution":"5 x 5 deg grid","status":"completed","dataPublishedTime":"2007-01-10T16:29:17Z","doiPublishedTime":null,"removedDataTime":null,"geographicExtent":{"ob_id":1,"bboxName":"","eastBoundLongitude":180.0,"westBoundLongitude":-180.0,"southBoundLatitude":-90.0,"northBoundLatitude":90.0},"verticalExtent":null,"result_field":{"ob_id":12,"dataPath":"/badc/ukmo-tovs/data","oldDataPath":[],"storageLocation":"internal","storageStatus":"online","volume":2952391620,"numberOfFiles":3049,"fileFormat":"The monthly data files are held at the BADC in the original VMS binary data format in which the data are encoded into 2-byte integer arrays, in records which contain a single day\'s data. The simplicity of the data format allows the data to be read on a wide variety of computer platforms with only very minor changes to the access routines.\\r\\n\\r\\nSee documentation links for further information on these formats."},"timePeriod":{"ob_id":3,"startTime":"1978-12-01T00:00:00Z","endTime":"1998-06-29T23:00:00Z"},"resultQuality":{"ob_id":2,"explanation":"See dataset associated documentation.","passesTest":true,"resultTitle":"CEDA Data Quality Statement","date":"2012-08-15"},"validTimePeriod":null,"procedureAcquisition":{"ob_id":33146,"uuid":"d5436a7c6e20464e94a7d6bf62c88c3d","short_code":"acq","title":"TOVS data acquisition onboard POES (1978-1998)"},"procedureComputation":null,"procedureCompositeProcess":null,"imageDetails":[],"discoveryKeywords":[{"ob_id":1138,"name":"NDGO0003"}],"permissions":[{"ob_id":2630,"accessConstraints":null,"accessCategory":"restricted","accessRoles":"tovs","label":"restricted: tovs group","licence":{"ob_id":12,"licenceURL":"https://artefacts.ceda.ac.uk/licences/specific_licences/ukmo_agreement.pdf","licenceClassifications":[{"ob_id":4,"classification":"academic"}]}}],"projects":[{"ob_id":4,"uuid":"fab53ee460e05f1b68e23657f4b6c5f4","short_code":"proj","title":"Met Office"}],"inspireTheme":[],"topicCategory":[],"phenomena":[6868,25382,25388,25843],"vocabularyKeywords":[],"identifier_set":[10,10948,10949,10950,10951],"observationcollection_set":[1],"responsiblepartyinfo_set":[27,28,21,25,26,22,24,23,72368]},{"ob_id":25,"uuid":"b621ef77b07d3c8e116b5b31fd5eb92b","title":"Daily Mean, Minimum and Maximum Central England Temperature series","abstract":"The longest available instrumental record of temperature in the world is now available at the BADC. The daily data starts in 1772. \\r\\n\\r\\nThe mean, minimum and maximum datasets are updated monthly, with data for a month usually available by the 3rd of the next month. A provisional CET value for the cur ...

# %%
from moles_api_v_3_client.api.rpis import rpis_list
from moles_api_v_3_client.models.rpis_list_role import RpisListRole
from collections import defaultdict

author_map = defaultdict(list)

ob_ids = [11, 25, 68]
res = rpis_list.sync_detailed(client=client, role=RpisListRole.AUTHOR, related_to_ob_id_in=ob_ids)
res.parsed.results

for author in res.parsed.results:
    ob_id = author.related_to.ob_id
    first_name = author.party.first_name
    last_name = author.party.last_name
    author_map[ob_id].append({
        'first_name': first_name,
        'last_name': last_name
    })

# %%
author_map
# Out:
# defaultdict(list,
#             {11: [{'first_name': '', 'last_name': 'Met Office'}],
#              25: [{'first_name': '',
#                'last_name': 'Hadley Centre for Climate Prediction and Research (MOHC)'}],
#              68: [{'first_name': '',
#                'last_name': 'Natural Environment Research Council (NERC)'},
#               {'first_name': 'Nick', 'last_name': 'Hewitt'},
#               {'first_name': 'Charlotte', 'last_name': 'Jones'}]})

# %%
import yaml

with open('schema.yml') as f:
    data = yaml.load(f, Loader=yaml.SafeLoader)

# %%
data['components']['schemas']['ObservationWrite']['required']

# %%
data['components']['schemas']['GeographicBoundingBoxWrite']

# %%
data['components']['schemas']['ObservationWrite']['required'] = ['title', 'status']

# %%
# save back to schema
with open('schema.yml', 'w') as f:
    yaml.dump(data, f, default_flow_style=False)

# %%
with open('debug.txt') as f:
    data = [_ for _ in f]

# %%
schema = data[3][17:-1]

# %%
schema.find('explode')

# %%
from moles_api_v_3_client.client import AuthenticatedClient

def read_token():
    with open('token.txt') as f:
        return f.readline()

URL = "http://localhost:8000/"

def input2obs(fh, client):
    uuids = []
    for line in fh:
        line = line.strip()
        if line == "":
            continue
        uuid = line.split()[0]
        if len(uuid) != 32:
            continue
        uuids.append(uuid)
   
    response = observations_list.sync_detailed(uuid_in=uuids, client=client) 
    return response
    

uuids_file = open('uuids.txt')
token = read_token()     
client = AuthenticatedClient(base_url=URL, token=token)

res = input2obs(uuids_file, client)
res.parsed.results

# %%
res.status_code
