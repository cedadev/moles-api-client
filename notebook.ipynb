# %%
from moles_api_v_3_client.client import AuthenticatedClient

def read_token():
    with open('token.txt') as f:
        return f.readline()

token = read_token()
URL = "http://localhost:8000/"
UUID = '7e23b82ec3bdc8e5297c0b623697c559'

client = AuthenticatedClient(base_url=URL, token=token)

# %% [markdown]
# ### GET

# %%
from moles_api_v_3_client.api.observations import observations_list

response = observations_list.sync_detailed(client=client)
response.parsed.results[:5]
# Out:
# [ObservationRead(abstract='These data consist of sets of 3-dimensional gridpoint analyses of the stratosphere which are produced by the Met Office using data from the TIROS Operational Vertical Sounder (TOVS) instruments onboard the NOAA (National Ocean and Atmospheric Administration) operational polar orbiters. TOVS consists of 3 instruments, the Stratospheric Sounding Unit (SSU) the Microwave Sounding Unit (MSU) and the High Resolution Infrared Sounder (HIRS). Daily radiance and geopotential height data are available on a 5 degree latitude / longitude global grid from December 1978 to April 1997. Software is provided to derive potential vorticity. Access permission required so that PI can monitor usage of data.', creation_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 183554, tzinfo=tzutc()), data_lineage='VMS files originally supplied to the BADC by the Met Office. Later data were supplied in the PP format.', data_published_time=datetime.datetime(2007, 1, 10, 16, 29, 17, tzinfo=tzutc()), discovery_keywords=[DiscoveryServiceIdRead(name='NDGO0003', ob_id=1138, additional_properties={})], doi_published_time=None, dont_harvest_from_projects=False, geographic_extent=GeographicBoundingBoxRead(bbox_name='', east_bound_longitude=180.0, north_bound_latitude=90.0, ob_id=1, south_bound_latitude=-90.0, west_bound_longitude=-180.0, additional_properties={}), identifier_set=[10, 10948, 10949, 10950, 10951], image_details=[], inspire_theme=[], keywords='ATMOSPHERICTEMPERATURE ATMOSPHERE ALTITUDE', language=<LanguageEnum.ENGLISH: 'English'>, last_updated_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 272326, tzinfo=tzutc()), latest_data_update_time=datetime.datetime(2004, 4, 21, 10, 50, 45, tzinfo=tzutc()), non_geographic_flag=False, ob_id=11, observationcollection_set=[1], permissions=[ConstraintsRead(access_category=<AccessCategoryEnum.RESTRICTED: 'restricted'>, access_constraints=None, access_roles='tovs', label='restricted: tovs group', licence=LicenceRead(licence_classifications=[LicenceClassificationRead(classification='academic', ob_id=4, additional_properties={})], licence_url='https://artefacts.ceda.ac.uk/licences/specific_licences/ukmo_agreement.pdf', ob_id=12, additional_properties={}), ob_id=2630, additional_properties={})], phenomena=[6868, 25382, 25388, 25843], procedure_acquisition=SimpleRead(ob_id=33146, short_code='acq', title='TOVS data acquisition onboard POES (1978-1998)', uuid='d5436a7c6e20464e94a7d6bf62c88c3d', additional_properties={}), procedure_composite_process=None, procedure_computation=None, projects=[SimpleRead(ob_id=4, short_code='proj', title='Met Office', uuid='fab53ee460e05f1b68e23657f4b6c5f4', additional_properties={})], publication_state=<PublicationStateCbbEnum.PUBLISHED: 'published'>, removed_data_reason='', removed_data_time=None, resolution='5 x 5 deg grid', responsiblepartyinfo_set=[27, 28, 21, 25, 26, 22, 24, 23, 72368], result_quality=DQConformanceResultRead(date=datetime.date(2012, 8, 15), explanation='See dataset associated documentation.', ob_id=2, passes_test=True, result_title='CEDA Data Quality Statement', additional_properties={}), result_field=RelatedResult(data_path='/badc/ukmo-tovs/data', ob_id=12, file_format="The monthly data files are held at the BADC in the original VMS binary data format in which the data are encoded into 2-byte integer arrays, in records which contain a single day's data. The simplicity of the data format allows the data to be read on a wide variety of computer platforms with only very minor changes to the access routines.\r\n\r\nSee documentation links for further information on these formats.", number_of_files=3049, old_data_path=[], storage_location=<StorageLocationEnum.INTERNAL: 'internal'>, storage_status=<StorageStatusEnum.ONLINE: 'online'>, volume=2952391620, additional_properties={}), status=<StatusEnum.COMPLETED: 'completed'>, time_period=TimePeriod(ob_id=3, start_time=datetime.datetime(1978, 12, 1, 0, 0, tzinfo=tzutc()), end_time=datetime.datetime(1998, 6 ...
#  ObservationRead(abstract='The longest available instrumental record of temperature in the world is now available at the BADC. The daily data starts in 1772. \r\n\r\nThe mean, minimum and maximum datasets are updated monthly, with data for a month usually available by the 3rd of the next month. A provisional CET value for the current month is calculated on a daily basis. The mean daily data series begins in 1772. Mean maximum and minimum daily and monthly data are also available, beginning in 1878. Yearly files are provided from 1998 onwards.\r\n\r\nThese historical temperature series are representative of the Midlands region in England, UK (a roughly triangular area of the United Kingdom enclosed by Bristol, Lancashire and London). \r\n\r\nThe following stations are used by the Met Office to compile the CET data: Rothamsted, Malvern, Squires Gate and Ringway.\r\n\r\nBut in November 2004, the weather station Stonyhurst replaced Ringway and revised urban warming and bias adjustments have now been applied to the Stonyhurst data after a period of reduced reliability from the station in the summer months. \r\n\r\nThe data set is compiled by the Met Office Hadley Centre.', creation_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 183554, tzinfo=tzutc()), data_lineage='HadCET was acquired in 1998 by the BADC from the Met Office Hadley Centre and was routinely updated until August 2022.', data_published_time=datetime.datetime(2007, 1, 5, 23, 59, 30, tzinfo=tzutc()), discovery_keywords=[DiscoveryServiceIdRead(name='NDGO0003', ob_id=1138, additional_properties={})], doi_published_time=None, dont_harvest_from_projects=False, geographic_extent=GeographicBoundingBoxRead(bbox_name='', east_bound_longitude=1.0, north_bound_latitude=54.0, ob_id=2, south_bound_latitude=51.0, west_bound_longitude=-4.0, additional_properties={}), identifier_set=[18, 8757], image_details=[157], inspire_theme=[], keywords='HadCET, temperature, Hadley, Met Office', language=<LanguageEnum.ENGLISH: 'English'>, last_updated_date=datetime.datetime(2022, 7, 22, 9, 15, 57, tzinfo=tzutc()), latest_data_update_time=datetime.datetime(2025, 1, 23, 14, 26, 19, tzinfo=tzutc()), non_geographic_flag=False, ob_id=25, observationcollection_set=[24, 43588], permissions=[ConstraintsRead(access_category=<AccessCategoryEnum.PUBLIC: 'public'>, access_constraints=None, access_roles=None, label='public: None group', licence=LicenceRead(licence_classifications=[LicenceClassificationRead(classification='any', ob_id=3, additional_properties={})], licence_url='http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/', ob_id=3, additional_properties={}), ob_id=2526, additional_properties={})], phenomena=[23369, 23370, 23371], procedure_acquisition=SimpleRead(ob_id=40, short_code='acq', title='Acquisition Process for: Daily Central England Temperature series', uuid='a4f4617005c54c79a578be4533963e6e', additional_properties={}), procedure_composite_process=None, procedure_computation=None, projects=[SimpleRead(ob_id=13164, short_code='proj', title='Met Office Hadley Centre - Observations and Climate', uuid='ce252c81a7bd4717834055e31716b265', additional_properties={})], publication_state=<PublicationStateCbbEnum.PUBLISHED: 'published'>, removed_data_reason='', removed_data_time=None, resolution='', responsiblepartyinfo_set=[50, 55, 49, 52, 53, 54, 56, 51, 53208, 55473, 148637], result_quality=DQConformanceResultRead(date=datetime.date(2014, 1, 28), explanation='Data is quality-controlled by the Met Office.', ob_id=4, passes_test=True, result_title='CEDA Data Quality Statement', additional_properties={}), result_field=RelatedResult(data_path='/badc/ukmo-cet/data/v1.0.0.0/daily', ob_id=26, file_format='ASCII', number_of_files=78, old_data_path=[43425], storage_location=<StorageLocationEnum.INTERNAL: 'internal'>, storage_status=<StorageStatusEnum.ONLINE: 'online'>, volume=1565592, additional_properties={}), status=<StatusEnum.SUPERSEDED: 'superseded'>, time_period=TimePeriod(ob_id=7, ...
#  ObservationRead(abstract='This dataset contains measurements of isoprene, pinene, camphene, d-3-carene, gamma-terpinene, limonene, methacrolein (pptv), methyl vinyl ketone and ethanol.\r\n\r\nOxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest (OP3-Danum-08) is a 3-year Consortium Grant of the Natural Environment Research Council (NERC), beginning 1 October 2007.\r\n\r\nThe objectives of the OP3 project are (i) to understand how emissions of reactive trace gases from a tropical rain forest mediate the production and processing of oxidants and particles in the troposphere, and (ii) to better understand the impact of these processes on local, regional and global scale atmospheric composition, chemistry and climate.', creation_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 183554, tzinfo=tzutc()), data_lineage='Data were obtained during ground-based measurement periods at the Danum Valley Research centre (7th April - 4th May 2008 and 21st June - 27th July 2008), and by the FAAM (Facility for Airborne Atmospheric Measurements) BAe 146 aircraft. Data were provided to the BADC as the OP3 campaign was underway, but may be updated with additional data.', data_published_time=datetime.datetime(2009, 7, 16, 16, 8, 39, tzinfo=tzutc()), discovery_keywords=[DiscoveryServiceIdRead(name='NDGO0003', ob_id=1138, additional_properties={})], doi_published_time=None, dont_harvest_from_projects=False, geographic_extent=GeographicBoundingBoxRead(bbox_name='', east_bound_longitude=118.0, north_bound_latitude=5.5, ob_id=3, south_bound_latitude=4.5, west_bound_longitude=117.0, additional_properties={}), identifier_set=[67], image_details=[2], inspire_theme=[], keywords='OP3-1, Chemistry', language=<LanguageEnum.ENGLISH: 'English'>, last_updated_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 272326, tzinfo=tzutc()), latest_data_update_time=datetime.datetime(2009, 8, 24, 10, 46, 29, tzinfo=tzutc()), non_geographic_flag=False, ob_id=68, observationcollection_set=[47], permissions=[ConstraintsRead(access_category=<AccessCategoryEnum.PUBLIC: 'public'>, access_constraints=None, access_roles=None, label='public: None group', licence=LicenceRead(licence_classifications=[LicenceClassificationRead(classification='any', ob_id=3, additional_properties={})], licence_url='http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/', ob_id=3, additional_properties={}), ob_id=2526, additional_properties={})], phenomena=[52353], procedure_acquisition=SimpleRead(ob_id=72, short_code='acq', title='Acquisition Process for: Data from York: Dual Column Gas Chromatograph-Flame Ionization Detector 1 (DC-GC-FID1) at Bukit Atur for the OP3-1 Campaign', uuid='2bda74813cc74c9a999564c955834ae3', additional_properties={}), procedure_composite_process=None, procedure_computation=None, projects=[SimpleRead(ob_id=70, short_code='proj', title='Oxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest (OP3-1) Project', uuid='f1de8b892d4093efb05caaba735a03c7', additional_properties={})], publication_state=<PublicationStateCbbEnum.PUBLISHED: 'published'>, removed_data_reason='', removed_data_time=None, resolution='', responsiblepartyinfo_set=[159, 164, 158, 166, 161, 162, 163, 160, 165, 75364, 54402], result_quality=DQConformanceResultRead(date=datetime.date(2014, 1, 26), explanation='Research data from the OP3 campaign.', ob_id=11, passes_test=True, result_title='CEDA Data Quality Statement', additional_properties={}), result_field=RelatedResult(data_path='/badc/op3/data/op3-1/york-dc-gc-fid1/2008', ob_id=69, file_format='Data are NASA Ames formatted', number_of_files=2, old_data_path=[], storage_location=<StorageLocationEnum.INTERNAL: 'internal'>, storage_status=<StorageStatusEnum.ONLINE: 'online'>, volume=166179, additional_properties={}), status=<StatusEnum.COMPLETED: 'completed'>, time_period=TimePeriod(ob_id=29, start_time=datetime.datetime(2008, 4, 3, 23, 0, tzinfo=tzutc()), end_time=datetime.dat ...
#  ObservationRead(abstract='This dataset contains measurements of ethane, propane, butane, cyclopentane, pentane and hexane.\r\n\r\nOxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest (OP3-Danum-08) is a 3-year Consortium Grant of the Natural Environment Research Council (NERC), beginning 1 October 2007.\r\n\r\nThe objectives of the OP3 project are (i) to understand how emissions of reactive trace gases from a tropical rain forest mediate the production and processing of oxidants and particles in the troposphere, and (ii) to better understand the impact of these processes on local, regional and global scale atmospheric composition, chemistry and climate.', creation_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 183554, tzinfo=tzutc()), data_lineage='Data were obtained during ground-based measurement periods at the Danum Valley Research centre (7th April - 4th May 2008 and 21st June - 27th July 2008), and by the FAAM (Facility for Airborne Atmospheric Measurements) BAe 146 aircraft. Data were provided to the BADC as the OP3 campaign was underway, but may be updated with additional data.', data_published_time=datetime.datetime(2009, 7, 16, 16, 17, 58, tzinfo=tzutc()), discovery_keywords=[DiscoveryServiceIdRead(name='NDGO0003', ob_id=1138, additional_properties={})], doi_published_time=None, dont_harvest_from_projects=False, geographic_extent=GeographicBoundingBoxRead(bbox_name='', east_bound_longitude=118.0, north_bound_latitude=5.5, ob_id=3, south_bound_latitude=4.5, west_bound_longitude=117.0, additional_properties={}), identifier_set=[72], image_details=[2], inspire_theme=[], keywords='OP3-1, Chemistry', language=<LanguageEnum.ENGLISH: 'English'>, last_updated_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 272326, tzinfo=tzutc()), latest_data_update_time=datetime.datetime(2009, 8, 24, 10, 48, 23, tzinfo=tzutc()), non_geographic_flag=False, ob_id=73, observationcollection_set=[47], permissions=[ConstraintsRead(access_category=<AccessCategoryEnum.PUBLIC: 'public'>, access_constraints=None, access_roles=None, label='public: None group', licence=LicenceRead(licence_classifications=[LicenceClassificationRead(classification='any', ob_id=3, additional_properties={})], licence_url='http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/', ob_id=3, additional_properties={}), ob_id=2526, additional_properties={})], phenomena=[51678], procedure_acquisition=SimpleRead(ob_id=76, short_code='acq', title='Acquisition Process for: Data from York: Dual Column GC-fid 2 at Bukit Atur for the OP3-1 Campaign', uuid='632bca88a12341a9b79068290e607e7d', additional_properties={}), procedure_composite_process=None, procedure_computation=None, projects=[SimpleRead(ob_id=70, short_code='proj', title='Oxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest (OP3-1) Project', uuid='f1de8b892d4093efb05caaba735a03c7', additional_properties={})], publication_state=<PublicationStateCbbEnum.PUBLISHED: 'published'>, removed_data_reason='', removed_data_time=None, resolution='', responsiblepartyinfo_set=[171, 176, 173, 174, 175, 178, 170, 172, 177, 75367, 54330], result_quality=DQConformanceResultRead(date=datetime.date(2014, 1, 26), explanation='Research data from the OP3 campaign.', ob_id=12, passes_test=True, result_title='CEDA Data Quality Statement', additional_properties={}), result_field=RelatedResult(data_path='/badc/op3/data/op3-1/york-dc-gc-fid2/2008', ob_id=74, file_format='Data are NASA Ames formatted', number_of_files=2, old_data_path=[], storage_location=<StorageLocationEnum.INTERNAL: 'internal'>, storage_status=<StorageStatusEnum.ONLINE: 'online'>, volume=165946, additional_properties={}), status=<StatusEnum.COMPLETED: 'completed'>, time_period=TimePeriod(ob_id=30, start_time=datetime.datetime(2008, 4, 3, 23, 0, tzinfo=tzutc()), end_time=datetime.datetime(2008, 4, 5, 23, 0, tzinfo=tzutc()), additional_properties={}), title='OP3-1 Campaign: York Alkane Dual Co ...
#  ObservationRead(abstract='This dataset contains measurements of ethene, propene and acetylene.\r\n\r\nOxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest (OP3-Danum-08) is a 3-year Consortium Grant of the Natural Environment Research Council (NERC), beginning 1 October 2007.\r\n\r\nThe objectives of the OP3 project are (i) to understand how emissions of reactive trace gases from a tropical rain forest mediate the production and processing of oxidants and particles in the troposphere, and (ii) to better understand the impact of these processes on local, regional and global scale atmospheric composition, chemistry and climate.', creation_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 183554, tzinfo=tzutc()), data_lineage='Data were obtained during ground-based measurement periods at the Danum Valley Research centre (7th April - 4th May 2008 and 21st June - 27th July 2008), and by the FAAM (Facility for Airborne Atmospheric Measurements) BAe 146 aircraft. Data were provided to the BADC as the OP3 campaign was underway, but may be updated with additional data.', data_published_time=datetime.datetime(2009, 7, 16, 16, 18, 59, tzinfo=tzutc()), discovery_keywords=[DiscoveryServiceIdRead(name='NDGO0003', ob_id=1138, additional_properties={})], doi_published_time=None, dont_harvest_from_projects=False, geographic_extent=GeographicBoundingBoxRead(bbox_name='', east_bound_longitude=118.0, north_bound_latitude=5.5, ob_id=3, south_bound_latitude=4.5, west_bound_longitude=117.0, additional_properties={}), identifier_set=[75], image_details=[2], inspire_theme=[], keywords='OP3-1, Chemistry', language=<LanguageEnum.ENGLISH: 'English'>, last_updated_date=datetime.datetime(2022, 7, 22, 9, 15, 57, 272326, tzinfo=tzutc()), latest_data_update_time=datetime.datetime(2009, 8, 24, 10, 51, 18, tzinfo=tzutc()), non_geographic_flag=False, ob_id=77, observationcollection_set=[47], permissions=[ConstraintsRead(access_category=<AccessCategoryEnum.PUBLIC: 'public'>, access_constraints=None, access_roles=None, label='public: None group', licence=LicenceRead(licence_classifications=[LicenceClassificationRead(classification='any', ob_id=3, additional_properties={})], licence_url='http://www.nationalarchives.gov.uk/doc/open-government-licence/version/3/', ob_id=3, additional_properties={}), ob_id=2526, additional_properties={})], phenomena=[52524], procedure_acquisition=SimpleRead(ob_id=80, short_code='acq', title='Acquisition Process for: Data from York: Dual Column GC-fid 3 at Bukit Atur for the OP3-1 Campaign', uuid='f5357b4d85a040ca9557e4dd3a474126', additional_properties={}), procedure_composite_process=None, procedure_computation=None, projects=[SimpleRead(ob_id=70, short_code='proj', title='Oxidant and Particle Photochemical Processes above a South-East Asian tropical rain forest (OP3-1) Project', uuid='f1de8b892d4093efb05caaba735a03c7', additional_properties={})], publication_state=<PublicationStateCbbEnum.PUBLISHED: 'published'>, removed_data_reason='', removed_data_time=None, resolution='', responsiblepartyinfo_set=[182, 181, 184, 187, 189, 186, 185, 183, 188, 75366, 54332], result_quality=DQConformanceResultRead(date=datetime.date(2014, 1, 26), explanation='Research data from the OP3 campaign.', ob_id=13, passes_test=True, result_title='CEDA Data Quality Statement', additional_properties={}), result_field=RelatedResult(data_path='/badc/op3/data/op3-1/york-dc-gc-fid3/2008', ob_id=78, file_format='Data are NASA Ames formatted', number_of_files=2, old_data_path=[], storage_location=<StorageLocationEnum.INTERNAL: 'internal'>, storage_status=<StorageStatusEnum.ONLINE: 'online'>, volume=76168, additional_properties={}), status=<StatusEnum.COMPLETED: 'completed'>, time_period=TimePeriod(ob_id=31, start_time=datetime.datetime(2008, 4, 3, 23, 0, tzinfo=tzutc()), end_time=datetime.datetime(2008, 4, 5, 23, 0, tzinfo=tzutc()), additional_properties={}), title='OP3-1 Campaign: York Alkene Dual Column GC-fid 2 measurements at ...

# %% [markdown]
# ### POST

# %%
from moles_api_v_3_client.api.observations import observations_create
from moles_api_v_3_client.models.observation_write import ObservationWrite, StatusEnum


model = Observati


















































onWrite(
    title='Example123',
    status=StatusEnum.ONGOING
)

response = observations_create.sync_detailed(client=client, body=model)

# %%
response.status_code.value
# Out:
# 201

# %%
import yaml

with open('schema.yml') as f:
    data = yaml.load(f, Loader=yaml.SafeLoader)

# %%
data['components']['schemas']['ObservationWrite']['required']
# Out:
# ['title', 'uuid']

# %%
data['components']['schemas']['ObservationWrite']['required'] = ['title', 'status']

# %%
# save back to schema
with open('schema.yml', 'w') as f:
    yaml.dump(data, f, default_flow_style=False)
